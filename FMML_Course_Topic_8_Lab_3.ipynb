# %% [markdown]
# <a href="https://colab.research.google.com/github/psssmanoj026/fmmlmanojlabs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 05:56:13--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   139MB/s    in 0.5s
#
# 2024-03-25 05:56:16 (139 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6220   1609.07272v1  Semi-supervised clustering methods incorporate...  stat
# 11234  1506.01709v1  Preference learning (PL) is a core area of mac...  stat
# 683    1711.02017v2  Neural networks (NNs) have begun to have a per...    cs
# 12771  1610.02373v1  Increasing the scalability of machine learning...    cs
# 31446  1803.04137v1  Deep supervised hashing has emerged as an infl...    cs
# ...             ...                                                ...   ...
# 13234  cs/9812002v1  A new training algorithm is presented for dela...    cs
# 22040   1404.0752v1  Bayesian networks are convenient graphical exp...  stat
# 15612  1511.01756v2  The present study is focused on the automatic ...    cs
# 21386  1801.10055v1  Generalized planning is concerned with the cha...    cs
# 40994   1404.3656v1  MOOCs have the potential to revolutionize high...    cs
#
#                                                    title  year  \
# 6220               Constraint-Based Clustering Selection  2016
# 11234                    The Preference Learning Toolbox  2015
# 683    NeST: A Neural Network Synthesis Tool Based on...  2017
# 12771         Distributed Averaging CNN-ELM for Big Data  2016
# 31446  Deep Class-Wise Hashing: Semantics-Preserving ...  2018
# ...                                                  ...   ...
# 13234  Training Reinforcement Neurocontrollers Using ...  1998
# 22040  An Efficient Search Strategy for Aggregation a...  2014
# 15612  "Pale as death" or "pâle comme la mort" : Froz...  2015
# 21386  Features, Projections, and Representation Chan...  2018
# 40994                   Methods for Ordinal Peer Grading  2014
#
#                                                 keywords
# 6220   [supervised, clustering, incorporate, supervis...
# 11234  [preference, relations, generated, increasing,...
# 683    [pervasive, applications, architecture, applic...
# 12771  [increasing, scalability, challenging, limitat...
# 31446  [supervised, influential, retrieval, convoluti...
# ...                                                  ...
# 13234  [algorithm, presented, reinforcement, existenc...
# 22040  [convenient, graphical, expressions, dimension...
# 15612  [automatic, identification, description, begin...
# 21386  [generalized, concerned, characterization, com...
# 40994  [potential, revolutionize, education, accessib...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6220     [supervised, clustering, incorporate, supervis...
# 11234    [preference, relations, generated, increasing,...
# 683      [pervasive, applications, architecture, applic...
# 12771    [increasing, scalability, challenging, limitat...
# 31446    [supervised, influential, retrieval, convoluti...
#                                ...
# 11369    [neuroprosthetic, interfaces, algorithm, movem...
# 25822    [discrimination, simplicity, important, effect...
# 14364    [automatic, construction, multilingual, knowle...
# 33338    [presented, evolutionary, algorithms, candidat...
# 5940     [calibrated, multivariate, regression, dimensi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8904 words.
# Out of those 4612 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee77e0ad-11c2-4a3c-b76b-6bcd0d46bafc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee77e0ad-11c2-4a3c-b76b-6bcd0d46bafc")) {                    Plotly.newPlot(                        "ee77e0ad-11c2-4a3c-b76b-6bcd0d46bafc",                        [{"x":["clusterings","procedure","unsupervised","clustering","approaches","individual","parameter","typically","incorporate","supervision","generated","similarity","supervised","selection","constraints","algorithms","outperforms","following","empirically","different","constraint","introduces","importance","preference","relations","increasing","accessible","preprocessing","efficient","incorporating","substantial","pervasive","operations","inefficient","connections","extensive","architectures","iteratively","applications","magnitude","architecture","redundancy","synthesis","automatically","conventional","experimental","parameters","generates","drawbacks","challenging","combining","limitations","averaging","distributed","asynchronously","experiment","classifier","additional","iteration","increased","researches","mapreduce","distribution","partition","scalability","carefully","sufficient","preserves","discriminant","databases","information","specifically","performance","semantics","optimization","expensive","embedding","penalizes","introduced","extracting","convolutional","vanishing","influential","preserving","motivated","corresponding","experiments","generally","surpasses","benchmark","variations","negligible","retrieval","guaranteed","noiseless","constructed","condition","consistency","recovered","simulations","measurement","probability","converges","dictionary","transformation","numerical","increases","including","theoretical","consistent","observation","manageable","demonstrated","knowledge","retaining","computationally","iterations","variables","association","relatedness","contribution","simulation","empirical","application","performing","efficiently","criterion","determine","thousands","screening","orthogonal","simultaneous","separately","regression","demanding","asymptotically","dimensional","irrelevant","displacement","correspondence","middlebury","technique","significantly","filtering","initialization","regularization","conceptually","disadvantage","estimation","smoothing","techniques","advantage","initializing","originally","descriptor","effectively","enhancements","approximate","outperform","detecting","generative","distinguish","classification","distributions","generating","demonstrate","predictions","detectors","effective","improving","procedures","confidence","particular","confident","calibrated","sufficiently","threshold","effectiveness","overconfident","inference","classifiers","preferences","translation","transformed","underlying","correspond","programming","compiling","preferred","dedicated","conceived","describes","reasoning","probabilistic","undirected","leveraging","attracted","difficulty","graphical","computational"],"y":[4,129,154,145,420,122,116,118,81,43,165,156,196,175,144,569,245,90,72,703,103,73,96,21,95,90,13,24,417,51,41,5,80,14,68,177,107,34,443,56,238,15,40,189,115,376,233,58,19,267,102,58,21,108,4,80,151,114,45,39,10,6,195,19,38,32,71,24,17,51,695,176,944,111,313,68,122,5,127,56,378,12,11,66,63,137,619,76,4,193,67,6,103,35,3,56,52,71,11,34,42,169,21,57,77,88,57,225,167,77,47,3,90,358,17,99,22,129,30,8,61,67,159,227,75,173,52,80,27,11,18,32,24,121,6,12,184,13,7,25,4,260,281,65,32,81,8,5,190,14,381,86,4,19,36,110,3,97,86,68,122,38,510,106,105,536,75,40,254,109,35,42,293,4,15,22,28,206,0,207,122,37,116,28,112,24,125,7,14,20,4,90,128,154,12,39,27,43,56,273],"type":"bar"},{"x":["clusterings","procedure","unsupervised","clustering","approaches","indiv ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4612,), (4612, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8208333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explanation</span> <span style='background-color:rgba(0, 255, 0, 0.3642384105960265);'>Mechanism</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Inferencing</span> <span style=''>Systems</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Explanation</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>facilities</span> <span style=''>are</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>feature</span> <span style=''>of</span> <span style=''>expert</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frameworks</span> <span style=''>It</span> <span style=''>is</span> <span style=''>an</span> <span style=''>area</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.40625);'>traditional</span> <span style=''>rule</span> <span style=''>based</span> <span style=''>expert</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frameworks</span> <span style=''>have</span> <span style=''>had</span> <span style=''>mixed</span> <span style=''>results</span> <span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3600000000000001);'>explanations</span> <span style=''>about</span> <span style=''>control</span> <span style=''>are</span> <span style=''>well</span> <span style=''>handled</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>facilities</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generating</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3600000000000001);'>explanations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concerning</span> <span style='background-color:rgba(0, 255, 0, 0.41782178217821775);'>knowledge</span> <span style=''>base</span> <span style=''>content</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>problem</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.7);'>examining</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>an</span> <span style=''>event</span> <span style=''>has</span> <span style=''>on</span> <span style=''>a</span> <span style=''>variable</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>within</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inferencing</span> <span style=''>system</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>any</span> <span style=''>effect</span> <span style=''>measure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operating</span> <span style=''>in</span> <span style=''>this</span> <span style=''>context</span> <span style=''>must</span> <span style=''>satisfy</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>Such</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>It</span> <span style=''>forms</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>facility</span> <span style=''>which</span> <span style=''>al ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Iterative</span> <span style=''>Hard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Thresholding</span> <span style=''>for</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>in</span> <span style=''>Genome</span> <span style=''>Wide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Association</span> <span style=''>Studies</span> <br/><br/><span style=''>A</span> <span style=''>genome</span> <span style=''>wide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>study</span> <span style=''>(GWAS)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlates</span> <span style=''>marker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>with</span> <span style=''>trait</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>in</span> <span style=''>a</span> <span style=''>sample</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individuals</span> <span style=''>Each</span> <span style=''>study</span> <span style=''>subject</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>genotyped</span> <span style=''>at</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitude</span> <span style=''>of</span> <span style=''>SNPs</span> <span style=''>(single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nucleotide</span> <span style=''>polymorphisms)</span> <span style=''>spanning</span> <span style=''>the</span> <span style=''>genome</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>subjects</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unrelated</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>at</span> <span style=''>random</span> <span style=''>and</span> <span style=''>that</span> <span style=''>trait</span> <span style=''>values</span> <span style=''>are</span> <span style=''>normally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normality</span> <span style=''>Over</span> <span style=''>the</span> <span style=''>past</span> <span style=''>decade</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>remarkably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>in</span> <span style=''>applying</span> <span style=''>GWAS</span> <span style=''>analysis</span> <span style=''>to</span> <span style=''>hundreds</span> <span style=''>of</span> <span style=''>traits</span> <span style=''>The</span> <span style=''>massive</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style=''>produced</span> <span style=''>in</span> <span style=''>these</span> <span style=''>studies</span> <span style=''>present</span> <span style=''>unique</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Penalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>with</span> <span style=''>LASSO</span> <span style=''>or</span> <span style=''>MCP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalties</span> <span style=''>is</span> <span style=''>capable</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.41782178217821775);'>Knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Elicitation</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3088480801335559);'>Inference</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.34867256637168137);'>Dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>in</span> <span style=''>a</span> <span style=''>small</span> <span style=''>sized</span> <span style=''>sample</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.9500000000000001);'>covariates</span> <span style=''>the</span> <span style=''>small</span> <span style=''>n</span> <span style=''>large</span> <span style=''>p</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.40157480314960636);'>challenging</span> <span style=''>This</span> <span style=''>setting</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>in</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>medicine</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>samples</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style=''>costly</span> <span style=''>or</span> <span style=''>even</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impossible</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3308270676691731);'>extensive</span> <span style=''>research</span> <span style=''>effort</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dedicated</span> <span style=''>to</span> <span style=''>finding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>for</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>However</span> <span style=''>a</span> <span style=''>valuable</span> <span style=''>source</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>domain</span> <span style=''>experts</span> <span style=''>has</span> <span style=''>not</span> <span style=''>yet</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3225806451612903);'>exploited</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style='background-color:rgba(0, 255, 0, 0.41782178217821775);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>elicitation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3088480801335 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Eigenmaps</span> <span style=''>from</span> <span style=''>Sparse</span> <span style=''>Noisy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Measurements</span> <br/><br/><span style=''>Manifold</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ubiquitous</span> <span style=''>in</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>but</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>when</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>or</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>To</span> <span style=''>date</span> <span style=''>little</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>tradeoff</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>and</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>We</span> <span style=''>present</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explorations</span> <span style=''>of</span> <span style=''>this</span> <span style=''>question</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenmaps</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>explore</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>behave</span> <span style=''>when</span> <span style=''>this</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occlusion</span> <span style=''>and</span> <span style=''>noise</span> <span style=''>Our</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	different (0.25197132616487455)
# 	experimental (0.13476702508960572)
# 	segmentation (0.06845878136200717)
# 	architecture (0.08530465949820788)
# 	knowledge (0.12831541218637993)
# 	representation (0.13799283154121864)
# 	information (0.24910394265232974)
# 	detection (0.12544802867383512)
# 	convolutional (0.13548387096774195)
# 	recognition (0.14301075268817204)
#
# Some Statistics words are:
# 	theoretical (0.14477611940298507)
# 	stochastic (0.13333333333333333)
# 	variables (0.14228855721393036)
# 	statistical (0.15323383084577114)
# 	estimation (0.17064676616915422)
# 	distribution (0.1791044776119403)
# 	algorithm (0.39303482587064675)
# 	inference (0.19502487562189055)
# 	dimensional (0.18955223880597014)
# 	regression (0.17860696517412936)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0c595313-46b0-421b-abae-b7b599f66719" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c595313-46b0-421b-abae-b7b599f66719")) {                    Plotly.newPlot(                        "0c595313-46b0-421b-abae-b7b599f66719",                        [{"x":["clusterings","procedure","unsupervised","clustering","approaches","individual","parameter","typically","incorporate","supervision","generated","similarity","supervised","selection","constraints","algorithms","outperforms","following","empirically","different","constraint","introduces","importance","preference","relations","increasing","accessible","preprocessing","efficient","incorporating","substantial","pervasive","operations","inefficient","connections","extensive","architectures","iteratively","applications","magnitude","architecture","redundancy","synthesis","automatically","conventional","experimental","parameters","generates","drawbacks","challenging","combining","limitations","averaging","distributed","asynchronously","experiment","classifier","additional","iteration","increased","researches","mapreduce","distribution","partition","scalability","carefully","sufficient","preserves","discriminant","databases","information","specifically","performance","semantics","optimization","expensive","embedding","penalizes","introduced","extracting","convolutional","vanishing","influential","preserving","motivated","corresponding","experiments","generally","surpasses","benchmark","variations","negligible","retrieval","guaranteed","noiseless","constructed","condition","consistency","recovered","simulations","measurement","probability","converges","dictionary","transformation","numerical","increases","including","theoretical","consistent","observation","manageable","demonstrated","knowledge","retaining","computationally","iterations","variables","association","relatedness","contribution","simulation","empirical","application","performing","efficiently","criterion","determine","thousands","screening","orthogonal","simultaneous","separately","regression","demanding","asymptotically","dimensional","irrelevant","displacement","correspondence","middlebury","technique","significantly","filtering","initialization","regularization","conceptually","disadvantage","estimation","smoothing","techniques","advantage","initializing","originally","descriptor","effectively","enhancements","approximate","outperform","detecting","generative","distinguish","classification","distributions","generating","demonstrate","predictions","detectors","effective","improving","procedures","confidence","particular","confident","calibrated","sufficiently","threshold","effectiveness","overconfident","inference","classifiers","preferences","translation","transformed","underlying","correspond","programming","compiling","preferred","dedicated","conceived","describes","reasoning","probabilistic","undirected","leveraging","attracted","difficulty","graphical","computational","estimates","extending","additionally","neighborhood","introduce","estimating","attention","regularized","augmenting","structure","considerable","processing","associated","dimensionality","collections","components","incremental","reconstructed","localizing","subsequent","reconstruction","component","remaining","unorganized","independently","sequential","addressed","degradations","understanding","literature","dictionaries","basically","invariant","compression","nevertheless","complexity","detection","automated","recognise","framework","inhomogeneity","pathological","coefficient","labelings","variability","diagnosis","validated","potentials","segmentation","grassmannian","delineation","malignant","monitoring","appearance","optimisation","discrimi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	overconfident
# 	procrustes
# 	delineates
# 	ventricle
# 	regressionclassification
# 	kantorovich
# 	bivariate
# 	circulant
# 	changepoint
# 	forthcoming
# 	distilling
# 	inhibited
# 	subsample
# 	internally
# 	intimately
# 	hermitian
# 	datapoint
# 	quantifiable
# 	gaussianization
# 	orthonormal
# Some words which never appear in Statistics papers:
# 	pervasive
# 	middlebury
# 	compiling
# 	conceived
# 	localizing
# 	unorganized
# 	recognise
# 	labelings
# 	predicate
# 	abbreviation
# 	orientations
# 	achievements
# 	postconditions
# 	hypernymy
# 	parameterize
# 	compilation
# 	evidential
# 	counterexamples
# 	proliferation
# 	obstacles

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075787401574804e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
